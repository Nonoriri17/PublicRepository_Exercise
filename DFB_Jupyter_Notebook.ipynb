# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Dante Franco Buendía

# %% [markdown]
# ## In this notebook, we will summarize some of the data science tools and its ecosystem

# %% [markdown]
# **Objectives:**
# - List popular libraries for Machine Learning
# - Make a table describing some popular Data Science Tools
# - Solve arithmetic problems with the help of coding

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R-Language
# 3. Julia
# 4. SQL
# 5. Java
# 6. C++

# %% [markdown]
# One of the essential parts of Data Science are their libraries. Here we put some examples of libraries used specifically for ML (Machine Learning):
# 1. Scikit-learn
# 2. Keras
# 3. Tensorflow
# 4. Pytorch

# %% [markdown]
# |Data Science Tools|
# |-----|
# |Jupyterlab
# |VsCode|
# |Google Colab|
# |R Studio|
# |Github|

# %% [markdown]
# ### Below are going to be presented some arithmetic examples expressed in Python:

# %%
#In this case, we will demonstrate why it´s important to solve properly arithmetic problems. 
#For this case, the first thing to do is the multiplication since it´s the operation inside the 
#parenthesis, which in this case the result is 3*4=12. After that, we only add 5 to the past result 
#to get at the end the value 17
(3*4)+5
# Out:
# 17

# %%
#Now we will transform minutes into hours. In order to do this we only have to divide the amount of 
#minutes by 60 
200/60
# Out:
# 3.3333333333333335
